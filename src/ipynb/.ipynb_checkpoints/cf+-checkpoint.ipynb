# %% [markdown]
# # データ前処理

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors


logs = pd.read_csv('../sample/medium/log_medium.csv')
users = pd.read_csv('../sample/medium/user_medium.csv')
products = pd.read_csv('../sample/medium/product_medium.csv')

df_u = users.drop(['age','address','last_login','last_purchase'], axis = 'columns')
df_p = products.drop(['category','shop','tag_price'],axis='columns')
df_po = pd.merge(df_p,logs, on='product_id')
df_pud = pd.merge(df_po,df_u, on='user_id',how='inner')
df_pu = df_pud.drop(['product_id','sub_category','order_id', 'user_id','price','tag_price'],axis='columns')

# %%
#割引カラムとセール商品カラムの追加
df_pud['discount'] = df_pud['price']/df_pud['tag_price']
for df_pud in [df_pud]:
    df_pud['isSaled'] = 0
    df_pud.loc[df_pud['discount'] < 1, 'isSaled'] = 1
df_pud.head()
# Out:
#    product_id        product_name sub_category   brand  order_id  user_id  \
# 0     1000001  Nike log pull over        sweat    nike   1000007  1000003
# 1     1000002  Nike sports hoodie       hoodie    nike   1000015  1000003
# 2     1000003  Adidas logo-hoodie       hoodie  adidas   1000006  1000003
# 3     1000009  Adidas track pants  other pants  adidas   1000014  1000003
# 4     1000002  Nike sports hoodie       hoodie    nike   1000001  1000001
#
#    tag_price  price  quantity user_name  discount  isSaled
# 0       3900   2000         1         C  0.512821        1
# 1       3600   1800         1         C  0.500000        1
# 2      14000  12600         1         C  0.900000        1
# 3      17000  17000         1         C  1.000000        0
# 4       3600   1800         1         A  0.500000        1

# %%
df_pud = df_pud.drop(['product_id','sub_category','order_id', 'user_id','price','tag_price','brand'],axis='columns')
df_pud.head()
# Out:
#          product_name  quantity user_name  discount  isSaled
# 0  Nike log pull over         1         C  0.512821        1
# 1  Nike sports hoodie         1         C  0.500000        1
# 2  Adidas logo-hoodie         1         C  0.900000        1
# 3  Adidas track pants         1         C  1.000000        0
# 4  Nike sports hoodie         1         A  0.500000        1

# %%
df_pud_pivot = df_pud.pivot(index='user_name', columns = 'product_name',values = 'quantity' ).fillna(0)
df_pud_pivot
# Out:
# product_name  Adidas logo-hoodie  Adidas track pants  Danton 2way bag  \
# user_name
# A                            0.0                 0.0              0.0
# B                            0.0                 0.0              1.0
# C                            1.0                 1.0              0.0
# D                            0.0                 0.0              0.0
# E                            0.0                 0.0              0.0
# F                            0.0                 0.0              0.0
# G                            0.0                 0.0              0.0
# H                            0.0                 0.0              0.0
#
# product_name  Danton boa-jacket   Danton inner down jacket  \
# user_name
# A                            0.0                       0.0
# B                            0.0                       0.0
# C                            0.0                       0.0
# D                            0.0                       0.0
# E                            0.0                       1.0
# F                            1.0                       0.0
# G                            0.0                       0.0
# H                            0.0                       0.0
#
# product_name  Freak Store Super big hoodie  Freaks Store Boa-jacket  \
# user_name
# A                                      0.0                      0.0
# B                                      0.0                      0.0
# C                                      0.0                      0.0
# D                                      1.0                      0.0
# E                                      0.0                      0.0
# F                                      0.0                      0.0
# G                                      0.0                      1.0
# H                                      0.0                      0.0
#
# product_name  Freaks Store noldick knit  Nike OH pants  Nike air force 1  \
# user_name
# A                                   0.0            0.0               1.0
# B                                   0.0            0.0               0.0
# C                                   0.0            0.0               0.0
# D                                   0.0            1.0               0.0
# E                                   0.0            0.0               0.0
# F                                   0.0            0.0               0.0
# G                                   1.0            0.0               1.0
# H                                   0.0            1.0               1.0
#
# product_name  Nike log pull over  Nike sports hoodie  \
# user_name
# A                            0.0                 1.0
# B                            0.0                 0.0
# C                            1.0                 1.0
# D                            0.0                 0.0
# E                            0.0                 0.0
# F                            0.0                 0.0
# G                            0.0                 1.0
# H                            0.0                 0.0
#
# product_name  The North Face Down jacket  The North Face Swead boots
# user_name
# A                                    0.0                         0.0
# B                                    1.0                         1.0
# C                                    0.0                         0.0
# D                                    0.0                         0.0
# E                                    0.0                         0.0
# F                                    0.0                         0.0
# G                                    0.0                         0.0
# H                                    0.0                         0.0

# %% [markdown]
# # レコメンド関数

# %%
#入力
matrix = df_pud_pivot
matrix_sparse = csr_matrix(df_pud_pivot.values)
product_list = df_pud
sale_parameter = 0.5

# %%
# Scikit-learnのライブラリを利用しモデルを作成
N = 5
knn = NearestNeighbors(n_neighbors=N,algorithm= 'brute', metric= 'cosine')
 
# 前処理したデータセットでモデルを訓練
model_knn = knn.fit(matrix_sparse)

#類似度を求める関数
def get_sim(matrix,user1,user2):
    distance, indice = model_knn.kneighbors(matrix.iloc[matrix.index== user1].values.reshape(1,-1),n_neighbors=N)
    for i in range(0, len(distance.flatten())):
        if  i > 0:
            if matrix.index[indice.flatten()[i]] == user2:
                return(1 - distance.flatten()[i])

#商品集合を求める関数
def get_product_set(user):
    s = set([])
    for i in range(len(matrix.loc[user].values)):
           if matrix.loc[user].values[i] > 0:
                s.add(matrix.columns[i])
    return(s)

#セール商品かどうかのチェック関数
def check_sale(product_name, product_list):
    return(product_list[product_list['product_name'] ==  product_name]['isSaled'].values[0])



import copy 
def get_recommend(user, top_N,mode):
    totals = {}  ; simSums = {}
    # 全てのユーザー、商品リストの作成
    list_product = []
    list_user = []
    for i in range(len(matrix.values)):
        list_product.append(matrix.columns[i])
        list_user.append(matrix.index[i])
    
    #自分以外のユーザーリスト
    list_others = copy.copy(list_user)
    list_others.remove(user)
    
    # 自分の購入商品集合
    set_user = get_product_set(user)
    
    for other in list_others:
        #本人がまだ購入していない商品の集合を取得
        set_other = get_product_set(other)
        set_new_product = set_other.difference(set_user)
        
        #あるユーザーと本人の類似度を計算
        sim = get_sim(matrix, user,other)
        
        if sim is not None:
            for item in set_new_product:
                #類似度 *  
                totals.setdefault(item,0)
                totals[item] += matrix.loc[other,item]*sim 
                if mode == 1:
                    if check_sale(item,product_list):
                         totals[item] += sale_parameter
                #ユーザーの類似度の積算値
                simSums.setdefault(item,0)
                simSums[item] += sim

    rankings = []
    #ランキングリストの作成
    for item,total in totals.items():
        if simSums[item] != 0:
            rankings.append((total/simSums[item],item))
    rankings.sort()
    rankings.reverse()
    return ([i[1] for i in rankings][:top_N])

# %%
get_recommend('A',5,0)
# Out:
# ['Nike log pull over',
#  'Nike OH pants',
#  'Freaks Store noldick knit',
#  'Freaks Store Boa-jacket',
#  'Adidas track pants']

# %%
#セール商品優先
get_recommend('A',5,1)
# Out:
# ['Nike log pull over',
#  'Adidas logo-hoodie',
#  'Nike OH pants',
#  'Freaks Store noldick knit',
#  'Freaks Store Boa-jacket']
